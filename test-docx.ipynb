# %%
# https://python-docx.readthedocs.io/en/latest/

# %%
import random

from docx import Document

document = Document(docx='vagtskema.docx')
document



idx = 0
n_gaster = 60 
nr = random.sample(range(1,n_gaster+1), n_gaster)
for i, row in enumerate(document.tables[0].rows):
    for j, cell in enumerate(row.cells):
        print(f'{i},{j} = {cell.text}')
        cell.text = 'BANAN'
document.save('vagtskema-.docx')
# Out:
# 0,0 = Havne-/ankervagt
#
# 0,1 = Vagthavende officer. Dag 08.00 – 16.00 og aften 16.00 – 08.00
# Vagthavende kvartermester. Dag 08.00 – 20.00 og nat 23.00 – 08.00
# 0,2 = BANAN
# 0,3 = BANAN
# 0,4 = BANAN
# 0,5 = BANAN
# 0,6 = BANAN
# 0,7 = BANAN
# 0,8 = BANAN
# 0,9 = BANAN
# 0,10 = BANAN
# 0,11 = BANAN
# 0,12 = BANAN
# 0,13 = BANAN
# 0,14 = BANAN
# 1,0 = Vagthavende officer (dag)
# 1,1 =
# 1,2 = BANAN
# 1,3 = BANAN
# 1,4 = BANAN
# 1,5 = BANAN
# 1,6 = Vagthavende ( aften )
# 1,7 = BANAN
# 1,8 = BANAN
# 1,9 = BANAN
# 1,10 = BANAN
# 1,11 =
# 1,12 = BANAN
# 1,13 = BANAN
# 1,14 = BANAN
# 2,0 = Kvartermester (dag)
# 2,1 =
# 2,2 = BANAN
# 2,3 = BANAN
# 2,4 = BANAN
# 2,5 = BANAN
# 2,6 = Vagthavende ( nat )
# 2,7 = BANAN
# 2,8 = BANAN
# 2,9 = BANAN
# 2,10 = BANAN
# 2,11 =
# 2,12 = BANAN
# 2,13 = BANAN
# 2,14 = BANAN
# 3,0 = ELEV vagtskifte
# 3,1 =
# 3,2 = BANAN
# 3,3 = BANAN
# 3,4 = BANAN
# 3,5 = BANAN
# 3,6 = Vagthavende ELEV
# 3,7 = BANAN
# 3,8 = BANAN
# 3,9 = BANAN
# 3,10 = BANAN
# 3,11 =
# 3,12 = BANAN
# 3,13 = BANAN
# 3,14 = BANAN
# 4,0 = Rutiner
# 4,1 =
# 4,2 = BANAN
# 4,3 = BANAN
# 4,4 = BANAN
# 4,5 = BANAN
# 4,6 = BANAN
# 4,7 = BANAN
# 4,8 = BANAN
# 4,9 = BANAN
# 4,10 = BANAN
# 4,11 = BANAN
# 4,12 = BANAN
# 4,13 = BANAN
# 4,14 = BANAN
# 5,0 = Rengøring på DÆK
# 5,1 =
# 5,2 = BANAN
# 5,3 = BANAN
# 5,4 = BANAN
# 5,5 = BANAN
# 5,6 = Badedag
# 5,7 = BANAN
# 5,8 = BANAN
# 5,9 = BANAN
# 5,10 = BANAN
# 5,11 =
# 5,12 = BANAN
# 5,13 = BANAN
# 5,14 = BANAN
# 6,0 = Rengøring om LÆ
# 6,1 =
# 6,2 = BANAN
# 6,3 = BANAN
# 6,4 = BANAN
# 6,5 = BANAN
# 6,6 = Fartøjstjeneste
# 6,7 = BANAN
# 6,8 = BANAN
# 6,9 = BANAN
# 6,10 = BANAN
# 6,11 =
# 6,12 = BANAN
# 6,13 = BANAN
# 6,14 = BANAN
# 7,0 = Tider
# 7,1 = 08-
#  10
# 7,2 = 10-
#  12
# 7,3 = 12-
#  14
# 7,4 = 14-
#  16
# 7,5 = 16-
#  18
# 7,6 = BANAN
# 7,7 = 18-
#  20
# 7,8 = 20-
#  22
# 7,9 = 22-
#  24
# 7,10 = 00-
#  02
# 7,11 = BANAN
# 7,12 = 02-
#  04
# 7,13 = 04-
#  06
# 7,14 = 06-
#  08
# 8,0 = Vagthavende officer
# 8,1 =
# 8,2 = BANAN
# 8,3 =
# 8,4 = BANAN
# 8,5 =
# 8,6 = BANAN
# 8,7 = BANAN
# 8,8 =
# 8,9 = BANAN
# 8,10 =
# 8,11 = BANAN
# 8,12 = BANAN
# 8,13 =
# 8,14 = BANAN
# 9,0 = Vagthavende KVTM
# 9,1 =
# 9,2 = BANAN
# 9,3 =
# 9,4 = BANAN
# 9,5 =
# 9,6 = BANAN
# 9,7 = BANAN
# 9,8 =
# 9,9 = BANAN
# 9,10 =
# 9,11 = BANAN
# 9,12 = BANAN
# 9,13 =
# 9,14 = BANAN
# 10,0 = Ordonnans/Radiovagt
# 10,1 =
# 10,2 =
# 10,3 =
# 10,4 =
# 10,5 =
# 10,6 = BANAN
# 10,7 =
# 10,8 =
# 10,9 =
# 10,10 =
# 10,11 = BANAN
# 10,12 =
# 10,13 =
# 10,14 =
# 11,0 = Udkig/Landgangsvagt
# 11,1 =
# 11,2 =
# 11,3 =
# 11,4 =
# 11,5 =
# 11,6 = BANAN
# 11,7 =
# 11,8 =
# 11,9 =
# 11,10 =
# 11,11 = BANAN
# 11,12 =
# 11,13 =
# 11,14 =
# 12,0 = Pejlegast A/B
# 12,1 =
# 12,2 = BANAN
# 12,3 =
# 12,4 = BANAN
# 12,5 =
# 12,6 = BANAN
# 12,7 = BANAN
# 12,8 =
# 12,9 = BANAN
# 12,10 =
# 12,11 = BANAN
# 12,12 = BANAN
# 12,13 =
# 12,14 = BANAN
# 13,0 = Dækselev i kabys
# 13,1 =
# 13,2 = BANAN
# 13,3 =
# 13,4 = BANAN
# 13,5 =
# 13,6 = BANAN
# 13,7 = BANAN
# 13,8 =
# 13,9 = BANAN
# 13,10 =
# 13,11 = BANAN
# 13,12 = BANAN
# 13,13 =
# 13,14 = BANAN
# 14,0 = HU
# (håndværksmæssig uddannelse)
# 14,1 =
#
#
# 14,2 = BANAN
# 14,3 =
# 14,4 = BANAN
# 14,5 =
# 14,6 = BANAN
# 14,7 = BANAN
# 14,8 =
# 14,9 = BANAN
# 14,10 =
# 14,11 = BANAN
# 14,12 = BANAN
# 14,13 =
# 14,14 = BANAN
# 15,0 = Søvagt
#
# 15,1 = 08 – 12
# 15,2 = BANAN
# 15,3 = 12 – 16
# ( 12 – 15 )
# 15,4 = BANAN
# 15,5 = 16 – 20
# ( 15 – 20 )
# 15,6 = BANAN
# 15,7 = BANAN
# 15,8 = 20 – 24
# 15,9 = BANAN
# 15,10 = 00 – 04
# 15,11 = BANAN
# 15,12 = BANAN
# 15,13 = 04 – 08
#
# 15,14 = BANAN
# 16,0 = Vagthavende officer
# 16,1 =
# 16,2 = BANAN
# 16,3 =
# 16,4 = BANAN
# 16,5 =
# 16,6 = BANAN
# 16,7 = BANAN
# 16,8 =
# 16,9 = BANAN
# 16,10 =
# 16,11 = BANAN
# 16,12 = BANAN
# 16,13 =
# 16,14 = BANAN
# 17,0 = Vagthavende KVTM
# 17,1 =
# 17,2 = BANAN
# 17,3 =
# 17,4 = BANAN
# 17,5 =
# 17,6 = BANAN
# 17,7 = BANAN
# 17,8 =
# 17,9 = BANAN
# 17,10 =
# 17,11 = BANAN
# 17,12 = BANAN
# 17,13 =
# 17,14 = BANAN
# 18,0 = Vagthavende ELEV
# 18,1 =
# 18,2 = BANAN
# 18,3 =
# 18,4 = BANAN
# 18,5 =
# 18,6 = BANAN
# 18,7 = BANAN
# 18,8 =
# 18,9 = BANAN
# 18,10 =
# 18,11 = BANAN
# 18,12 = BANAN
# 18,13 =
# 18,14 = BANAN
# 19,0 = Ordonnans
# 19,1 =
# 19,2 = BANAN
# 19,3 =
# 19,4 = BANAN
# 19,5 =
# 19,6 = BANAN
# 19,7 = BANAN
# 19,8 =
# 19,9 = BANAN
# 19,10 =
# 19,11 = BANAN
# 19,12 = BANAN
# 19,13 =
# 19,14 = BANAN
# 20,0 = Udkig
# 20,1 =
# 20,2 = BANAN
# 20,3 =
# 20,4 = BANAN
# 20,5 =
# 20,6 = BANAN
# 20,7 = BANAN
# 20,8 =
# 20,9 = BANAN
# 20,10 =
# 20,11 = BANAN
# 20,12 = BANAN
# 20,13 =
# 20,14 = BANAN
# 21,0 = Bjærgemærs
# 21,1 =
# 21,2 = BANAN
# 21,3 =
# 21,4 = BANAN
# 21,5 =
# 21,6 = BANAN
# 21,7 = BANAN
# 21,8 =
# 21,9 = BANAN
# 21,10 =
# 21,11 = BANAN
# 21,12 = BANAN
# 21,13 =
# 21,14 = BANAN
# 22,0 = Rorgænger
# 22,1 =
# 22,2 = BANAN
# 22,3 =
# 22,4 = BANAN
# 22,5 =
# 22,6 = BANAN
# 22,7 = BANAN
# 22,8 =
# 22,9 = BANAN
# 22,10 =
# 22,11 = BANAN
# 22,12 = BANAN
# 22,13 =
# 22,14 = BANAN
# 23,0 = Udsætningsgast A
# 23,1 =
# 23,2 = BANAN
# 23,3 =
# 23,4 = BANAN
# 23,5 =
# 23,6 = BANAN
# 23,7 = BANAN
# 23,8 =
# 23,9 = BANAN
# 23,10 =
# 23,11 = BANAN
# 23,12 = BANAN
# 23,13 =
# 23,14 = BANAN
# 24,0 = Udsætningsgast B
# 24,1 =
# 24,2 = BANAN
# 24,3 =
# 24,4 = BANAN
# 24,5 =
# 24,6 = BANAN
# 24,7 = BANAN
# 24,8 =
# 24,9 = BANAN
# 24,10 =
# 24,11 = BANAN
# 24,12 = BANAN
# 24,13 =
# 24,14 = BANAN
# 25,0 = Udsætningsgast C
# 25,1 =
# 25,2 = BANAN
# 25,3 =
# 25,4 = BANAN
# 25,5 =
# 25,6 = BANAN
# 25,7 = BANAN
# 25,8 =
# 25,9 = BANAN
# 25,10 =
# 25,11 = BANAN
# 25,12 = BANAN
# 25,13 =
# 25,14 = BANAN
# 26,0 = Udsætningsgast D
# 26,1 =
# 26,2 = BANAN
# 26,3 =
# 26,4 = BANAN
# 26,5 =
# 26,6 = BANAN
# 26,7 = BANAN
# 26,8 =
# 26,9 = BANAN
# 26,10 =
# 26,11 = BANAN
# 26,12 = BANAN
# 26,13 =
# 26,14 = BANAN
# 27,0 = Udsætningsgast E
# 27,1 =
# 27,2 = BANAN
# 27,3 =
# 27,4 = BANAN
# 27,5 =
# 27,6 = BANAN
# 27,7 = BANAN
# 27,8 =
# 27,9 = BANAN
# 27,10 =
# 27,11 = BANAN
# 27,12 = BANAN
# 27,13 =
# 27,14 = BANAN
# 28,0 = Pejlegast A/B
# 28,1 =
# 28,2 = BANAN
# 28,3 =
# 28,4 = BANAN
# 28,5 =
# 28,6 = BANAN
# 28,7 = BANAN
# 28,8 =
# 28,9 = BANAN
# 28,10 =
# 28,11 = BANAN
# 28,12 = BANAN
# 28,13 =
# 28,14 = BANAN
# 29,0 = HU (håndværksmæssig uddannelse)
# 29,1 =
# 29,2 = BANAN
# 29,3 =
# 29,4 = BANAN
# 29,5 =
# 29,6 = BANAN
# 29,7 = BANAN
# 29,8 =
# 29,9 = BANAN
# 29,10 =
# 29,11 = BANAN
# 29,12 = BANAN
# 29,13 =
# 29,14 = BANAN
# 30,0 = Dækselev i kabys
# 30,1 =
# 30,2 = BANAN
# 30,3 =
# 30,4 = BANAN
# 30,5 =
# 30,6 = BANAN
# 30,7 = BANAN
# 30,8 =
# 30,9 = BANAN
# 30,10 =
# 30,11 = BANAN
# 30,12 = BANAN
# 30,13 =
# 30,14 = BANAN
